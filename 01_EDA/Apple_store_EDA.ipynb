# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('/content/drive/MyDrive/appleAppData.csv')
#df = pd.read_csv('/content/sample_data/appleAppData.csv', names=['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating', 'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version', 'Price', 'Currency', 'Free', 'DeveloperId', 'Developer', 'Developer_Url', 'Developer_Website', 'Average_User_Rating', 'Reviews', 'Current_Version_Score', 'Current_Version_Reviews'])

# %%
df[df['Released'].duplicated()]
# Out:
#                                    App_Id  \
# 90     com.heinemann.prompting.nonfiction
# 92               com.react.native.f6notes
# 132               com.abcbookcambodia.com
# 138                     stickervegetables
# 168    id.co.daihatsu.daihatsuownermanual
# ...                                   ...
# 25273              org.webdata.easytasks1
# 25274                    com.easy.tawseel
# 25275                     com.sanjit.user
# 25276                   com.sanjit.driver
# 25277                    se.easyteams.app
#
#                                                 App_Name  \
# 90                        F&P Prompting Guide Nonfiction
# 92                                               F6Notes
# 132                                    ABC Book Cambodia
# 138    ABC Children’s First Words – Learn the English...
# 168                              Daihatsu Owner's Manual
# ...                                                  ...
# ...

# %%
df[df['Released'].duplicated()].sum()
# Out:
# App_Id                     com.heinemann.prompting.nonfictioncom.react.na...
# App_Name                   F&P Prompting Guide NonfictionF6NotesABC Book ...
# AppStore_Url               https://apps.apple.com/us/app/f-p-prompting-gu...
# Primary_Genre              EducationStickersShoppingGamesBookBookBookBook...
# Content_Rating             4+4+4+4+4+4+4+4+4+12+4+4+4+4+4+4+4+4+4+4+4+4+4...
# Size_Bytes                                                      644948364817
# Required_IOS_Version       11.010.09.05.111.012.411.19.08.011.010.35.111....
# Released                   2018-12-31T19:03:28Z2021-04-29T07:00:00Z2021-0...
# Updated                    2020-02-27T11:00:21Z2021-05-04T15:43:46Z2021-0...
# Version                    5.11.0.41.0.01.01.01.31.21.0.11.21.11.01.01.0....
# Price                                                                5360.67
# Currency                   USDUSDUSDUSDUSDUSDUSDUSDUSDUSDUSDUSDUSDUSDUSDU...
# ...

# %%
df[df['Released'].duplicated()].sort_values(by='Released')
# Out:
#                                           App_Id  \
# 20576                          com.ifrontiers.V1
# 23775      com.ThetaOilfieldServices.XAnimatePro
# 15081  com.oceanhousemedia.BookBBSayTheirPrayers
# 15085       com.oceanhousemedia.BookBBGoldenRule
# 22197                                     QuickD
# ...                                          ...
# 14644                                  app.cacmu
# 14291                com.expoplatform.dwtc.app34
# 17916    de.lecturio.whitelabel.easysoftcustomer
# 24362                       com.neonapps.scanner
# 24496                 am.biblesociety.deafsbible
#
#                              App_Name  \
# 20576                         V1 Golf
# 23775                    XANIMATE-PRO
# 15081  Berenstain - Say Their Prayers
# 15085  Berenstain Bears - Golden Rule
# 22197  Dictionary English Spanish Eng
# ...                               ...
# 14644                   Cacmu Contigo
# 14291                          CABSAT
# ...
